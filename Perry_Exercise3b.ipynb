# %%
install.packages("devtools")
devtools::install_github("sfsheath/cawd")
install.packages("sp")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# Skipping install of 'cawd' from a github remote, the SHA1 (928f175f) has not changed since last install.
#   Use `force = TRUE` to force installation
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library("sp")
library("cawd")
par(mai=c(0,0,0,0))
plot(awmc.roman.empire.200.sp)
# Out:
# plot without title

# %%
data()

# %%
par(mai=c(0,0,0,0))
plot(darmc.shipwrecks.sp)
# Out:
# plot without title

# %% [markdown]
# Looks like a constellation

# %%
par(mai=c(0,0,0,0))
plot(ramphs.sp)
# Out:
# plot without title

# %%
par(mai=c(0,0,0,0))
plot(nomisma.greek.mints.sp)
# Out:
# plot without title

# %% [markdown]
# I have no idea what any of this means, honestly

# %%
par(mai=c(0,0,0,0))
plot(darmc.rats.1to1500.sp)
# Out:
# plot without title
